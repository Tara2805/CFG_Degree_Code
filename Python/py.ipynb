# %%
#Printing strings

cats = 10
cans = 2


total_cans = 10 * 2
output = str(cats) + " cats eat " + str(total_cans) + " cans"


print(output)

# %%
#Joining strings together

my_words = "hello new world"
print(" ".join(my_words))

# %%
#Concatenation
cats = 10
cans = 2
total_cans_needed = cats * cans
catsOutput = "we need £{} for {} cats".format(total_cans_needed, cats)
print(catsOutput)

username = 'Jenny_1995'
age = 23

output = "{} is {} years old".format(username, age)
print(output)

# %%
#Interpolation
cats = 10
cans = 2
total_cans_needed = cats * cans
catsOutput = "we need " + str(total_cans_needed) + " cans for  " + str(cats) + " cats"
print(catsOutput)

# %%
#Arrays
my_words = ['apple', 'banana', 'kiwi']
', '.join(my_words)

# %%
#Getting ascii etc 
ord('P')
chr(86)

# %%
#Slicing/splicing
S = 'ABCDEFGHI'
print(S[2:7])


S = 'Hippopotamus'
print(S[-7:-2])


S = 'ABCDEFGHI'
print(S[2:7:2])


S='ABCDEFGI'
print(S[::-1])


S='ABCDEFGI'
print(S[-1::-1])

# %%
#palindrome
word = input("Give me a palindrome please: ")
word_reverse = word[::-1]


print(word_reverse)

# %%
#For
for number in range(10):
    print(number)

fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)

for x in "banana":
  print(x)

fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
  if x == "banana":
    break

fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    break
  print(x)

fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue
  print(x)

for x in range(6):
  print(x)


for x in range(2, 30, 3):
  print(x)


for x in range(6):
  if x == 3: break
  print(x)
else:
  print("Finally finished!")

adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]


for x in adj:
  for y in fruits:
    print(x, y)

new_list = []


for number in range(5):
     new_list.append(number)


print(new_list)

# %%
#Floats
temperature = input("what is the temperature?")
is_freezing = float(temperature) <= 0.0
print("The temperature is freezing {}".format(temperature))

burger_price = input("What is the burger price?")
is_under = float(burger_price) <= 10.00
print ("Burger is within budget: {}".format(is_under))

meal_price = float(input("how much did the meal cost? "))


discount_choice = (input("do you have a discount y/n?"))
discount_applicable = meal_price >= 20.00 and discount_choice == "y"
discount_price = 0.10 + meal_price


if discount_applicable:
    meal_price = meal_price - discount_price
    print("discount applied")
else:
    print("no discount")

# %%
#User input and boolean
mars_choice = input("would you like to visit mars Y/N?")
is_willing = mars_choice == "Y"
affordable = input("can you afford to visit Mars Y/N?")
can_afford = affordable == "Y"


should_visit = is_willing and can_afford


print("you can visit {}".format(should_visit))

burger_price = input("What is the burger price?")
is_under = float(burger_price) <= 10.00
Veggie_option = input("is food veggie or not? Y/N")
critera = Veggie_option == "Y"


should_visit = is_under and critera
print ("Restaurant meets criteria: {}".format(should_visit))

burger_price = input("What is the burger price?")
Veggie_option = input("is food veggie or not? Y/N")


is_under = float(burger_price) <= 10.00


critera = Veggie_option == "Y"
should_visit = is_under and critera


if should_visit:
    print("Restaurant meets criteria: {}".format(should_visit))


if not should_visit:
    print ("Restaurant does not meet criteria: {}".format(should_visit))

name = input("what is your name?")
is_admin = name =="admin"


password = input("Enter your password")
is_password_correct = password == "dinosaurs"


if is_admin and is_password_correct:
    print("Welcome")
else:
    print("go away")

# %%
#Elif
dog_size = int(input("what is your dogs size? "))


if dog_size >75:
    print("Big dog")
elif dog_size < 10:
    print("really small dog")
elif dog_size < 25:
    print("slightly small dog")
else:
    print("average dog")


temperature = float(input("input the pizzas temperature: "))


if temperature > 200:
    print("The oven is too hot if the temperature is over 200")
elif temperature < 150:
    print("The oven is too cold")
elif temperature == 180:
    print("The oven is at the perfect temperature")
else:
    print("The temperature is close enough")

# %%
#Import random
import random

sides = int(input("how many sides does the die have? "))
random_integer = random.randint(1,sides)
print("you rolled a {}".format(random_integer))

import random


def flip_coin():
    random_number = random.randint(1,2)
    if random_number == 1:
        side = "heads"
    else:
        side = "tails"
    return side


choice = input('heads or tails: ')
result = flip_coin()


is_winner = choice == result
if is_winner:
    print("YOU WIN")
else:
    print("YOU LOSE")
   
print('The coin landed on {}'.format(result))

# %%
#Functions
def isPalindrome(string):
    #this only works if word is longer than 2 letters
    #this just for display, not efficient
    leftindex = 0
    rightindex = len(string) - 1
    while leftindex < rightindex:
        if string[leftindex] != string[rightindex]:
            return False
        #left has to go forwards and the right backwards
        leftindex += 1
        rightindex -= 1
        return True
    #or
    #return string == string [::-1]
   
#or
    #this is more efficient
    #Okay so the second code will stop as soon as it reaches a different letter so would give an answer quicker more efficiently
#def isPalindrome(string):
#   l = len ==1:
#           return true
#   return string == string[::-1]

print(isPalindrome('hannah'))  # should return True

print(isPalindrome('mummy'))  # should return False

print(isPalindrome('I'))  # should return True

# %%
#Palindrome
def isPalindrome(string):


    return string == string[::-1]


# def isPalindrome(string):
#     l = len(string)
#     if l == 1:
#         return True
#     return string == string[::-1]


def isPalindrome(string):
 leftIdx = 0
 rightIdx = len(string) - 1
 while leftIdx < rightIdx:
    if string[leftIdx] != string[rightIdx]:
      return False
    leftIdx += 1
    rightIdx -=1
 return True

print(isPalindrome('hannah'))  # should return True

print(isPalindrome('mummy'))  # should return False

print(isPalindrome('I'))  # should return True

# %%
#Inbuilt methods
print("Hello world")

print("Example string".upper())
# .lower()
# .title()
# .count('o')
# .captalize()
# 'Our example string object'.endswith('ject')
# 'Our example string object'.endswith('mock')
# 'To make a nice cuppa you need: tea, milk, sugar and a cookie '.split(',')
# 'Our example string object'.replace('p', '#')
#.title()

print('spaghetti')

food = 'spaghetti'
print(food)

oranges = 12
cost_per_orange = 0.5
total_cost = oranges * cost_per_orange
output = "{} oranges costs£{}".format(oranges, total_cost)
print(output)

cats = 10
cans = 2
total_cans_needed = cats * cans
catsOutput = "we need £{} for {} cats".format(total_cans_needed, cats)

# %%
#List values
clothes = [
   "shorts",
    "shoes",
     "t-shirt",
]
#all do the same thing

if clothes[0] == 'shorts':
     clothes[0] = 'warm coat'
     print(clothes)


if clothes[0] == "shorts":
     clothes.remove("shorts")
     clothes.insert(0, "warm coat")
     print(clothes)

if clothes.index('shorts') == 0:
     clothes[0] = 'warm coat'
     print(clothes)

if clothes[0] == "shorts":
     clothes.pop(0)
     clothes.insert(0, "warm coat")
     print(clothes)

# %%
#Len()
game_scores = [1,45,35,67,8,94,345,234,22,567,345,22]


print(f"number of scores: {len(game_scores)}")
print(f"Highest score: {max(game_scores)}")
print(f"Lowest score: {min(game_scores)}")

# %%
#Reading arrays
student_name = input("which student are you looking for?")
#general list can have duplicates, a set has to have unique values
students = ["Mark", "Francis", "Sophie", "Alice"]
if student_name in students:
    print("{} is in the class".format(student_name))
else:
    print("{} is not in the class".format(student_name))
    shopping_list = ["bread", "cheese", "pop tarts", "carrots"]


if "bread" in shopping_list:
    shopping_list.append("butter")
    print(shopping_list)


fridge = ["cheese", "pizza", "coke"]
if "milk" not in fridge:
    print("You have no milk, go to the shop")

costs = [8.56,74.56,24.67,3.45]
total_cost = 0


for cost in costs:
    total_cost += cost


print(total_cost)
#total cost
costs = [8.30, 7.12, 5.01, 1.00, 0.99, 5.92, 3.50]
total_cost = 0


for cost in costs:
     total_cost = total_cost + cost
     total_cost += cost


print(total_cost)

costs = [8.30, 7.12, 5.01, 1.00, 0.99, 5.92, 3.50]
total = sum(costs)


print(total)

# %%
#Indexes
#List values can be accessed using their index in square brackets

student_names = ['Diedre', 'Hank', 'Helena', 'Salome']
# print(student_names[0:2])

#List indexes start counting from 0

#
# student_names = [
#     'Diedre',    # index 0
#     'Hank',      # index 1
#     'Helena',    # index 2
#     'Salome'     # index 3
# ]
#
# print(student_names[0])

#You can also set the values in lists using their indexes, similar to how you would set a variable

student_names = [
    'Diedre',    # index 0
    'Hank',      # index 1
    'Helena',    # index 2
    'Salome'     # index 3
]
#
# student_names[1] = 'Joshua'
# print(student_names)

# student_names.append('Joshua')
# print(student_names)
# print(student_names)
#
# student_names.insert(3, 'Joshua')
# print(student_names)
#
# student_names.pop()
# print(student_names)
#
# student_names.pop(2)
# print(student_names)
# print(student_names)

# %%
#.append()
#The .append() method is used to add items to a list

students = [
     'Diedre', 'Hank', 'Helena', 'Salome',
 ]
student_name = input('What is the name of the new student? ')

students.append(student_name)

print(students)

# %%
#Count
#Counting the total number of items in a list using a for loop

student_names = ['Diedre', 'Hank', 'Helena', 'Salome']
count = 0

for student_name in student_names:
     # count = count + 1
     count += 1

print(count)

student_names = ["Mark", "Francis", "Sophie", "Alice"]

for student_name in student_names:
    print(student_name)

count = 0

for student_name in student_names:
    count +=1
    print(student_names)

# %%
#Min max
list = [34, 67, 89, 44, 1, 24]

max = 0
for each in list:
    if each > max:
        max = each
print(f"The highest number is: {max}")

# %%
#List comprehension: creating lists
#Using LIST COMPREHENSION to create a new list

new_list = [num for num in range(5) if num % 2 != 0]

print(new_list)
#Another example:
#Using FOR LOOP to create a new list filtering out some values

new_list = []

for word in ['cat', 'dog', 'rat', 'cow']:
     if word != 'rat':
         new_list.append(word)

print(new_list)

#Using LIST COMPREHENSION to create a new list filtering out some values

new_list = [word for word in ['cat', 'dog', 'rat', 'cow'] if word != 'rat']

print(new_list)

#write a list comprehension expression to build a new list of EVEN numbers ONLY from range(5)

new_list = [i for i in range(5) if i % 2 == 0]

print(new_list)

# %%
#Dictionaries
#Values in a dictionary are accessed using their keys

person = {
    'name': 'Jessica',
    'age': 23,
    'height': 172
}

print(person['name'])

#Print the values of name, post_code and street_number from the dictionary

place = {
     'name': 'The Anchor',
     'post_code': 'E14 6HY',
     'street_number': '54',
     'location': {
         'longitude': 127,
         'latitude': 63,
     }
 }

print(place['name'])
print(place['post_code'])
print(place['street_number'])

print(place['location']['longitude'])
print(place['location']['latitude'])

location = place['location']

print(location['longitude'])
print(location['latitude'])

#Dictionaries in Lists --> Putting dictionaries inside a list is very common

people = [
     {'name': 'Jessica', 'age': 23},
     {'name': 'Trisha', 'age': 24},
]

for person in people:
     print(person['name'])
     print(person['age'])

#Using a for loop, output the values name, colour and price of each dictionary in the list

fruits = [
     {'name': 'apple', 'colour': 'red', 'price': 0.12},
     {'name': 'banana', 'colour': 'yellow', 'price': 0.2},
     {'name': 'pear', 'colour': 'green', 'price': 0.19},
]

for fruit in fruits:
     print(fruit['name'])
     print(fruit['colour'])
     print(fruit['price'])

# %%
#Import random
#Random choice -- The choice() function in the random module returns a random item from a list

import random

colours = ['red', 'green', 'blue']
chosen_colour = random.choice(colours)

print(chosen_colour)

# %% [markdown]
# Tuples
# Tuple: a Tuple is similar to List except that the objects in tuple are IMMUTABLE which means we CANNOT change the elements of a tuple once assigned.
#
# ● Tuple syntax uses ( ) brackets
#
# ● Tuple behaves very similar to
# list
#
# order = ('croissant', 'coffee', 'juice')

# %%
order = ('croissant', 'coffee', 'juice')
#
print(order[1])
#
for item in order:
    print('Order item: ' + item)

# %% [markdown]
# Sets
# set: set is an unordered and unindexed collection of UNIQUE items in Python.
#
# ● Unordered means when we display the elements of a set, it will come out in a random order.
# ● Unindexed means, we cannot access the elements of a set using the indexes like we can do in list and tuples.
# ● Set elements are unique. Duplicate elements are not allowed.
# ● Set uses {}
#
# my_set = {1,2,3,4,5, 'hi', 7}

# %%
my_set = {1,2,3,4,5, 'hi', 7}
#
#
# # We can add new elements to a set
my_set = {1,2,3}
my_set.add(4)
print(my_set)
#
#
# # No duplicate values in Set -- Try adding a new value to a set if it is already there
numbers = {1,2,3,4,5}
numbers.add(3)
print(numbers)
#
#
# # Convert a list to a set to remove duplicates
words = ['hi', 'potatoe', 'car', 'hi', 'hi', 'car']
result = set(words)
print(result)

# %%
#Text files: reading and writing
row = ('name', 'John')
dictionary = dict(row)
print(dictionary)

file = open('test_file_two.txt', 'w')

file.write('Hello I am writting')

file.close()

movie_quotes = [
    "\nI'm gonna make him an offer he can't refuse. (THE GODFATHER)",
    "\nMay the Force be with you. (STAR WARS)",
    "\nThere's no place like home. (THE WIZARD OF OZ)",
]

file = open('test_file_two.txt', 'a')
file.writelines(movie_quotes)
file.close()

new_todo = input("What do you need to do?:")

with open('todo.txt', 'r') as text_file:
    todo = text_file.read()

todo = todo + new_todo + '\n'
print(todo)

with open('todo.txt', 'a') as text_file:
    text_file.write(todo)

to_do = input("Add a new to-do item: ")
with open("todolist.txt", 'a') as text_file:
    text_file.write(to_do + '\n')


with open("todolist.txt", 'r') as text_file:
    contents = text_file.read()

text_file.close()

print(contents)

# %%
#CSV files
import csv
field_names =['name', 'age']

data =[
    {'name': 'Jill', 'age': 32},
    {'name': 'Hannah', 'age': 23}
]

with open('team.csv', 'w+') as csv_file:
    spreadsheet = csv.DictWriter(csv_file, fieldnames=field_names)


    spreadsheet.writeheader()
    spreadsheet.writerows(data)

#this is when there is an existing file and we extract some data, the file was sent in slack

import csv

with open('trees.csv', 'r') as csv_file:
    spreadsheet = csv.DictReader(csv_file)


    heights = []


    for row in spreadsheet:
        tree_height = row['height']
        heights.append(tree_height)

shortest_height = min(heights)
print(shortest_height)

#this file also preexists in the slack folder
# so in the file it will extract how many times a word has occured
fname = input('Enter file name: ' )
search_word = input('Enter word to be searched: ').lower()

count = 0
with open(fname, 'r') as text_file:
    for line in text_file:
        line = line.strip()#gets rid of space before & after the input

        print(line + 'before_______')

        words = line.lower()

        words = line.split()

        for word in words:
            if(word == search_word):
                count = count +1

print('Occurances of word' + search_word)
print(count)

fname = input('Enter file name: ')
search_word = input('Enter word to be searched: ').lower()

count = 0
with open(fname, 'r') as text:
    for line in text:
        line = line.strip()

        print(line + '----------')

        words = line.lower()

        for char in '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~':
            line = line.replace(char, "")

        words = line.split()
        print(words )

        for word in words:
            if(word == search_word):
                count = count + 1

print("Occurrences of the word: " + search_word)
print(count)
